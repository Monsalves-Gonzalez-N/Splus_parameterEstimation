# %%
import pandas as pd
import ray
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
import plotly.graph_objects as go
from itertools import combinations
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import (train_test_split, GridSearchCV,
                                    StratifiedKFold, StratifiedShuffleSplit,
                                    cross_val_score)
from sklearn.metrics import make_scorer, recall_score, precision_score, f1_score, classification_report
from sklearn.ensemble import RandomForestRegressor
import numpy as np
import joblib
from itertools import combinations
from sklearn.preprocessing import MinMaxScaler
import os
# Out:
# 2023-11-23 22:41:43.933875: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-11-23 22:41:44.004025: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-23 22:41:44.303239: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-23 22:41:44.303287: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-23 22:41:44.305429: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-23 22:41:44.464393: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-23 22:41:44.466189: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-23 22:41:45.405249: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
def optimize_hyperparameters(X, y):
    # Initialize a BalancedRandomForestClassifier
    clf = RandomForestRegressor()

    # Define hyperparameters grid
    param_grid = {
        'n_estimators': [200,500,800],
        'max_features': ['sqrt', 'log2'],
        'max_depth': [10, 30, None]    }

    # Grid search with cross-validation
    grid_search = GridSearchCV(estimator=RandomForestRegressor(),
                           param_grid=param_grid,
                           scoring='neg_mean_squared_error',  # For regression
                           cv=10,  # Number of cross-validation folds
                           verbose=2,
                           n_jobs=-1  # Use all available CPUs
                          ) 
    grid_search.fit(X, y)

    # Return best parameters and best score
    return grid_search

# %%
def preprocess_features(data,columns,bad_values):
    """
    Realiza el preprocesamiento de las características especificadas.

    Args:
    - data (pd.DataFrame): DataFrame original con los datos.

    Returns:
    - data (pd.DataFrame): DataFrame procesado con características adicionales y filas inválidas eliminadas.
    """
    
    # Busca valores 999 o -999 en las columnas especificadas
    invalid_values = data[columns].isin([bad_values, -bad_values]).sum()

    # Filtra y muestra solo las columnas que tienen estos valores inválidos
    columns_with_invalids = invalid_values[invalid_values > 0]

    if columns_with_invalids.empty:
        print(f" Todas las columnas tienen datos válidos, sin valores {bad_values} o -{bad_values}.")
    else:
        print(f"Las siguientes columnas tienen valores {bad_values} o -{bad_values}:\n{columns_with_invalids}")

    # Filtra el DataFrame para excluir filas con valores 999 o -999 en las columnas especificadas
    data = data[~data[columns].isin([bad_values, -bad_values]).any(axis=1)].reset_index(drop=True)

    return data

# %%
class DataFrameScaler:
    def __init__(self):
        self.scalers = {}

    def scale(self, df):
        """
        Escala las columnas del DataFrame entre Min y Max 
        """
        scaled_df = df.copy()
        for column in df.columns:
            scaler = MinMaxScaler()
            scaled_df[column] = scaler.fit_transform(df[column].values.reshape(-1, 1)).flatten()
            self.scalers[column] = scaler
        return scaled_df

    def inverse_scale(self, df):
        """
        Devuelve el DataFrame escalado a su estado original.
        """
        original_df = df.copy()
        for column in df.columns:
            scaler = self.scalers.get(column)
            if scaler:
                original_df[column] = scaler.inverse_transform(df[column].values.reshape(-1, 1)).flatten()
        return original_df

# %%
def create_color_columns(mag_features, df):
    """
    Crea columnas de colores en el DataFrame df basadas en las combinaciones de mag_features.
    
    Parámetros:
    - mag_features: Lista de características para hacer combinaciones y crear colores.
    - df: DataFrame donde se añadirán las nuevas columnas de colores.
    
    Retorna:
    - df: DataFrame modificado con las nuevas columnas de colores.
    - colors: Lista de los nombres de las nuevas columnas de colores.
    """
    colors = []
    for v in combinations(mag_features, 2):
        df[f"{v[0]}-{v[1]}"] = df[v[0]] - df[v[1]]
        colors.append(f"{v[0]}-{v[1]}")
    return df, colors

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
import joblib

def process_columns(df_original, columns_name, colors, survey, idx,giagiants):
    for column in columns_name[idx]:
        column_save = column.replace("[","").replace("]","").replace("/","")
        test = survey + '_' + str(column_save)

        # Crear directorios para los resultados
        directory_path = f'/home/nicolas/nico/Data/Data_Splus/regresion/data/{giagiants}/{survey}/{column_save}'
        if not os.path.exists(directory_path):
            os.makedirs(directory_path)
        AnasCores = df_original.copy(deep=True)
        x_columns = colors
        y_column = [column]
        print(y_column)
        # Preprocesamiento
        AnasCores = preprocess_features(AnasCores, AnasCores[x_columns + y_column].columns, 999)
        AnasCores = preprocess_features(AnasCores, AnasCores[x_columns + y_column].columns, 9999)
        AnasCores = preprocess_features(AnasCores, AnasCores[x_columns + y_column].columns, np.nan)

        # División de datos
        X_train, X_test, Y_train, Y_test = train_test_split(AnasCores[x_columns], AnasCores[column], 
                                                            test_size=0.2, random_state=11085)

        # Optimización de hiperparámetros
        grid_search = optimize_hyperparameters(X_train, Y_train)
        best_params, best_score = grid_search.best_params_, grid_search.best_score_
        params_file = os.path.join(directory_path, f'best_param_{test}.csv')
        pd.DataFrame([best_params]).to_csv(params_file, index=False)

        # Entrenamiento del modelo
        rf_regressor = RandomForestRegressor(**best_params)
        rf_regressor.fit(X_train, Y_train)
        
        #Guardar dataframe
        AnasCores.loc[X_train.index,"split"] = "train"
        AnasCores.loc[X_test.index,"split"] = "test"
        df_file = os.path.join(directory_path, f'df_{test}.csv')
        AnasCores.to_csv(df_file, index=False)

        # Guardar el modelo entrenado
        model_file = os.path.join(directory_path, f'{test}.sav')
        joblib.dump(rf_regressor, model_file)

# %%
survey = ["Apogee","Galah","LamostMedium","LamostLow"]

# %%
path = '/home/nicolas/nico/Data/Data_Splus/regresion/data/'

# %%
file_names = ["Apogee",
    "Galah",
    "LamostMedium",
    "LamostLow",
]

# %%
apoge_columns = ['TEFF', 'LOGG', 'FE_H', 'ALPHA_M', 'C_FE', 'CA_FE', 'N_FE',
       'NI_FE', 'MG_FE', 'SI_FE']
galah_columns = ['Teff', 'logg', '[Fe/H]', '[alpha/Fe]', '[Li/Fe]',
       '[C/Fe]', '[O/Fe]', '[Na/Fe]', '[Mg/Fe]', '[Al/Fe]', '[Si/Fe]',
       '[K/Fe]', '[Ca/Fe]', '[Sc/Fe]', '[Ti/Fe]', '[Ti2/Fe]',
        '[Cr/Fe]', '[Mn/Fe]', '[Co/Fe]', '[Ni/Fe]',
       '[Cu/Fe]', '[Zn/Fe]', '[Y/Fe]']
lamostMedium_columns = ['teff_cnn', 'logg_cnn', 'feh_cnn', 'alpha_m_cnn', 'c_fe', 'ca_fe',
       'n_fe', 'mg_fe', 'si_fe', 'ni_fe']
lamostLow_columns = ['teff', 'logg', 'feh',"alpha_m"]
columns_name = [apoge_columns,galah_columns,lamostMedium_columns,lamostLow_columns]
s_plus_filter = ['u', 'J378', 'J395', 'J410',
       'J430', 'g', 'J515', 'r', 'J660', 'i', 'J861', 'z']

# %%
for idx,survey in enumerate(file_names):
    df_original = pd.read_csv(f'{path}/{survey}.csv')  
    df_original = preprocess_features(df_original,s_plus_filter,999)
    df_original = preprocess_features(df_original,s_plus_filter,9999)
    df_original = preprocess_features(df_original,s_plus_filter,np.nan)
    df_original = df_original.loc[((df_original[s_plus_filter] < 24).all(axis=1))&
               ((df_original[s_plus_filter] > 8 ).all(axis=1))]
    df_original,colors = create_color_columns(s_plus_filter, df_original)
    scaler = DataFrameScaler()
    df_original[colors] = scaler.scale(df_original[colors])
    process_columns(df_original.loc[df_original["giagiants"]==1], columns_name, colors, survey, idx,"giagiants")
    process_columns(df_original.loc[df_original["giagiants"]!=1], columns_name, colors, survey, idx,"dwarfs")
# Out:
#  Todas las columnas tienen datos válidos, sin valores 999 o -999.
#  Todas las columnas tienen datos válidos, sin valores 9999 o -9999.
#  Todas las columnas tienen datos válidos, sin valores nan o -nan.
# ['TEFF']
#  Todas las columnas tienen datos válidos, sin valores 999 o -999.
#  Todas las columnas tienen datos válidos, sin valores 9999 o -9999.
#  Todas las columnas tienen datos válidos, sin valores nan o -nan.
# Fitting 10 folds for each of 18 candidates, totalling 180 fits
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=   4.8s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=   4.8s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=500; total time=  17.2s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=200; total time=  15.6s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=800; total time= 1.0min
# /home/nicolas/miniconda3/envs/RF/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=200; total time=   6.2s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=   4.8s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=500; total time=  17.9s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=200; total time=  15.7s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=800; total time= 1.0min
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=500; total time=  17.4s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=800; total time=  29.8s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=200; total time=  12.1s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=800; total time=  48.4s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=800; total time=  37.0s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=800; total time= 1.2min
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=500; total time=  20.6s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=200; total time=  17.8s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=800; total time= 1.2min
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=500; total time=  20.8s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=200; total time=  18.3s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=800; total time= 1.2min
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=200; total time=   7.1s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=500; total time=  17.8s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=200; total time=  17.6s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=800; total time= 1.2min
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=200; total time=   7.1s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=500; total time=  17.8s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=200; total time=  17.7s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=800; total time= 1.2min
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=800; total time=  32.2s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=500; total time=  38.7s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=800; total time=  47.9s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=800; total time=  32.1s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=500; total time=  38.8s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=800; total time=  48.2s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=500; total time=  17.6s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=800; total time=  29.8s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=200; total time=  12.1s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=800; total time=  48.5s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=800; total time= 1.0min
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=800; total time=  37.6s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=800; total time= 1.2min
# [CV] END max_depth=None, max_features=sqrt, n_estimators=800; total time= 1.0min
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=500; total time=  20.6s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=800; total time=  33.0s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=500; total time=  34.1s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=200; total time=  17.8s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=800; total time= 1.1min
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=800; total time=  32.1s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=500; total time=  39.1s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=800; total time=  49.5s
# [CV] END max_depth=None, max_features=log2, n_estimators=200; total time=  12.0s
# [CV] END max_depth=None, max_features=log2, n_estimators=800; total time=  43.2s
# [CV] END max_depth=None, max_features=log2, n_estimators=200; total time=  13.7s
# [CV] END max_depth=None, max_features=log2, n_estimators=800; total time=  42.7s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=200; total time=   7.1s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=   5.5s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=800; total time=  32.9s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=200; total time=  13.6s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=500; total time=  34.2s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=500; total time=  44.8s
# [CV] END max_depth=None, max_features=log2, n_estimators=800; total time=  40.4s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=200; total time=   7.1s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=   5.5s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=800; total time=  32.8s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=200; total time=  13.6s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=500; total time=  34.1s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=500; total time=  45.5s
# [CV] END max_depth=None, max_features=log2, n_estimators=800; total time=  41.8s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=800; total time=  36.6s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=500; total time=  44.3s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=200; total time=  17.7s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=500; total time=  44.9s
# [CV] END max_depth=None, max_features=log2, n_estimators=800; total time=  37.3s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=800; total time=  36.9s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=500; total time=  44.5s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=200; total time=  17.9s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=500; total time=  44.6s
# [CV] END max_depth=None, max_features=log2, n_estimators=800; total time=  37.0s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=200; total time=   6.3s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=   4.8s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=500; total time=  18.0s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=200; total time=  15.6s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=200; total time=  12.1s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=500; total time=  29.8s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=200; total time=  15.6s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=500; total time=  39.2s
# [CV] END max_depth=None, max_features=log2, n_estimators=800; total time=  39.8s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=200; total time=   6.3s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=   4.8s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=500; total time=  18.0s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=200; total time=  15.6s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=200; total time=  12.1s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=500; total time=  29.9s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=200; total time=  15.5s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=500; total time=  39.2s
# [CV] END max_depth=None, max_features=log2, n_estimators=800; total time=  39.8s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=500; total time=  17.6s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=800; total time=  29.7s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=200; total time=  11.9s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=500; total time=  30.0s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=200; total time=  15.6s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=500; total time=  39.3s
# [CV] END max_depth=None, max_features=log2, n_estimators=800; total time=  38.4s
# ['LOGG']
#  Todas las columnas tienen datos válidos, sin valores 999 o -999.
#  Todas las columnas tienen datos válidos, sin valores 9999 o -9999.
#  Todas las columnas tienen datos válidos, sin valores nan o -nan.
# Fitting 10 folds for each of 18 candidates, totalling 180 fits
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=200; total time=   7.1s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=500; total time=  17.9s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=200; total time=  17.7s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=800; total time= 1.2min
# [CV] END max_depth=None, max_features=log2, n_estimators=200; total time=  13.9s
# [CV] END max_depth=None, max_features=log2, n_estimators=500; total time=  31.9s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=200; total time=   7.2s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=500; total time=  19.4s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=200; total time=  15.3s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=800; total time= 1.0min
# /home/nicolas/miniconda3/envs/RF/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=500; total time=  17.5s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=800; total time=  29.7s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=200; total time=  12.0s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=500; total time=  30.2s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=200; total time=  15.5s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=500; total time=  39.2s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=200; total time=   6.0s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=   6.1s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=500; total time=  18.6s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=200; total time=  15.2s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=800; total time= 1.0min
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=800; total time=  39.8s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=800; total time= 1.2min
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=800; total time=  39.9s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=800; total time= 1.2min
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=800; total time=  40.8s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=800; total time= 1.2min
# [CV] END max_depth=None, max_features=log2, n_estimators=200; total time=  13.2s
# [CV] END max_depth=None, max_features=log2, n_estimators=500; total time=  33.9s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=200; total time=   7.1s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=500; total time=  20.6s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=200; total time=  17.2s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=800; total time= 1.2min
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=200; total time=   7.1s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=500; total time=  17.9s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=200; total time=  17.7s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=800; total time= 1.2min
# [CV] END max_depth=None, max_features=log2, n_estimators=200; total time=  13.8s
# [CV] END max_depth=None, max_features=log2, n_estimators=500; total time=  34.6s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=200; total time=   7.2s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=500; total time=  20.6s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=200; total time=  17.4s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=800; total time= 1.2min
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=   5.4s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=   7.7s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=800; total time=  32.9s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=800; total time= 1.2min
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=800; total time=  32.0s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=500; total time=  39.3s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=800; total time=  48.2s
# [CV] END max_depth=None, max_features=log2, n_estimators=200; total time=  12.0s
# [CV] END max_depth=None, max_features=log2, n_estimators=500; total time=  29.6s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=200; total time=   6.3s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=   7.1s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=500; total time=  19.0s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=500; total time=  38.2s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=800; total time=  47.3s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=800; total time=  35.2s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=500; total time=  38.0s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=800; total time=  46.8s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=800; total time=  35.3s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=500; total time=  38.2s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=800; total time=  46.9s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=800; total time=  35.2s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=500; total time=  38.0s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=800; total time=  47.1s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=800; total time=  35.5s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=500; total time=  38.5s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=800; total time=  47.4s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=500; total time=  17.5s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=800; total time=  29.8s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=200; total time=  12.1s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=500; total time=  30.0s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=200; total time=  15.8s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=500; total time=  40.3s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=200; total time=   6.3s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=   7.1s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=500; total time=  20.5s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=500; total time=  43.5s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=800; total time=  52.8s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=800; total time=  39.8s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=500; total time=  43.3s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=800; total time=  53.8s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=500; total time=  17.5s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=800; total time=  29.7s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=200; total time=  12.1s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=500; total time=  30.0s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=200; total time=  15.6s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=500; total time=  39.2s
# [CV] END max_depth=None, max_features=log2, n_estimators=800; total time=  38.6s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=500; total time=  20.5s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=800; total time=  29.5s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=200; total time=  11.7s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=500; total time=  29.2s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=200; total time=  15.2s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=800; total time= 1.0min
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=   5.4s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=   5.4s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=500; total time=  19.8s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=500; total time=  44.3s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=800; total time=  54.7s
# [CV] END max_depth=None, max_features=log2, n_estimators=500; total time=  33.6s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=500; total time=  23.4s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=800; total time=  32.8s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=500; total time=  33.5s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=200; total time=  17.4s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=800; total time= 1.1min
# [CV] END max_depth=None, max_features=log2, n_estimators=200; total time=  13.7s
# [CV] END max_depth=None, max_features=log2, n_estimators=500; total time=  33.6s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=200; total time=   6.3s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=500; total time=  18.3s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=200; total time=  15.2s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=500; total time=  38.0s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=800; total time=  47.3s
# [CV] END max_depth=None, max_features=log2, n_estimators=200; total time=  11.7s
# [CV] END max_depth=None, max_features=log2, n_estimators=800; total time=  41.3s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=   5.4s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=   8.1s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=800; total time=  33.9s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=200; total time=  13.7s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=500; total time=  34.5s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=500; total time=  44.7s
# [CV] END max_depth=None, max_features=log2, n_estimators=800; total time=  38.0s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=800; total time=  39.8s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=500; total time=  43.5s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=200; total time=  17.4s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=500; total time=  43.2s
# [CV] END max_depth=None, max_features=log2, n_estimators=800; total time=  36.3s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=800; total time=  32.1s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=500; total time=  39.5s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=800; total time=  48.5s
# [CV] END max_depth=None, max_features=log2, n_estimators=200; total time=  12.0s
# [CV] END max_depth=None, max_features=log2, n_estimators=500; total time=  29.7s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=200; total time=   6.2s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=   7.1s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=500; total time=  18.5s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=200; total time=  15.4s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=200; total time=  11.8s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=500; total time=  29.4s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=200; total time=  15.2s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=500; total time=  38.4s
# [CV] END max_depth=None, max_features=log2, n_estimators=800; total time=  39.1s
# [CV] END max_depth=None, max_features=log2, n_estimators=200; total time=  12.1s
# [CV] END max_depth=None, max_features=log2, n_estimators=500; total time=  29.5s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=200; total time=   6.2s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=   7.1s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=500; total time=  18.5s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=200; total time=  15.2s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=200; total time=  11.7s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=500; total time=  29.4s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=200; total time=  15.2s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=500; total time=  39.6s
# [CV] END max_depth=None, max_features=log2, n_estimators=800; total time=  38.5s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=800; total time=  32.2s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=500; total time=  38.9s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=800; total time=  48.1s
# [CV] END max_depth=None, max_features=log2, n_estimators=200; total time=  12.0s
# [CV] END max_depth=None, max_features=log2, n_estimators=500; total time=  29.5s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=200; total time=   6.3s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=   7.1s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=500; total time=  18.6s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=200; total time=  15.3s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=200; total time=  11.8s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=500; total time=  29.4s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=200; total time=  15.3s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=500; total time=  38.8s
# [CV] END max_depth=None, max_features=log2, n_estimators=800; total time=  39.0s
# ['FE_H']
#  Todas las columnas tienen datos válidos, sin valores 999 o -999.
#  Todas las columnas tienen datos válidos, sin valores 9999 o -9999.
# Las siguientes columnas tienen valores nan o -nan:
# FE_H    28
# dtype: int64
# Fitting 10 folds for each of 18 candidates, totalling 180 fits
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=800; total time=  40.8s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=800; total time=  58.2s
# /home/nicolas/miniconda3/envs/RF/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [CV] END max_depth=None, max_features=log2, n_estimators=200; total time=  13.5s
# [CV] END max_depth=None, max_features=log2, n_estimators=500; total time=  33.6s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=200; total time=   7.4s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=500; total time=  20.4s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=200; total time=  16.1s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=800; total time=  57.3s
# [CV] END max_depth=None, max_features=log2, n_estimators=200; total time=  13.5s
# [CV] END max_depth=None, max_features=log2, n_estimators=500; total time=  33.0s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=200; total time=   7.3s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=500; total time=  20.2s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=200; total time=  16.0s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=800; total time=  57.8s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=   4.7s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=   7.0s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=500; total time=  18.3s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=200; total time=  14.1s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=800; total time=  56.8s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=800; total time=  39.6s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=800; total time= 1.1min
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=800; total time=  39.6s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=800; total time= 1.1min
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=800; total time=  40.2s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=800; total time= 1.1min
# [CV] END max_depth=None, max_features=log2, n_estimators=200; total time=  11.8s
# [CV] END max_depth=None, max_features=log2, n_estimators=500; total time=  28.9s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=200; total time=   7.4s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=500; total time=  20.3s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=200; total time=  15.9s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=800; total time= 1.1min
# [CV] END max_depth=None, max_features=log2, n_estimators=200; total time=  13.4s
# [CV] END max_depth=None, max_features=log2, n_estimators=500; total time=  28.5s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=200; total time=   7.4s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=500; total time=  20.3s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=200; total time=  15.9s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=800; total time= 1.1min
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=800; total time=  35.0s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=500; total time=  35.2s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=800; total time=  43.5s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=200; total time=   7.0s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=   5.5s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=500; total time=  20.5s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=500; total time=  44.5s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=800; total time=  54.4s
# [CV] END max_depth=None, max_features=log2, n_estimators=500; total time=  32.4s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=500; total time=  23.3s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=800; total time=  32.8s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=200; total time=  13.3s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=800; total time=  53.8s
# [CV] END max_depth=None, max_features=log2, n_estimators=200; total time=  13.4s
# [CV] END max_depth=None, max_features=log2, n_estimators=800; total time=  40.6s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=800; total time=  35.0s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=500; total time=  35.8s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=800; total time=  44.0s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=800; total time=  35.3s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=500; total time=  36.0s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=800; total time=  44.2s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=800; total time=  39.7s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=500; total time=  43.5s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=200; total time=  17.3s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=500; total time=  43.6s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=200; total time=   6.4s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=   7.7s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=500; total time=  20.0s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=500; total time=  39.6s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=800; total time=  49.4s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=500; total time=  20.6s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=800; total time=  33.0s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=500; total time=  34.4s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=200; total time=  17.8s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=800; total time= 1.0min
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=500; total time=  23.3s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=800; total time=  33.0s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=500; total time=  33.7s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=200; total time=  17.5s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=800; total time=  59.9s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=500; total time=  23.2s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=800; total time=  32.6s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=500; total time=  31.0s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=200; total time=  16.0s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=800; total time=  58.3s
# [CV] END max_depth=None, max_features=log2, n_estimators=200; total time=  13.5s
# [CV] END max_depth=None, max_features=log2, n_estimators=500; total time=  30.5s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=500; total time=  23.1s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=800; total time=  32.4s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=200; total time=  12.4s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=800; total time=  50.0s
# [CV] END max_depth=None, max_features=log2, n_estimators=200; total time=  12.4s
# [CV] END max_depth=None, max_features=log2, n_estimators=800; total time=  39.5s
# [CV] END max_depth=None, max_features=log2, n_estimators=200; total time=  11.8s
# [CV] END max_depth=None, max_features=log2, n_estimators=500; total time=  28.7s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=200; total time=   6.2s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=   7.4s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=500; total time=  18.3s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=200; total time=  14.1s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=200; total time=  11.3s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=500; total time=  27.4s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=200; total time=  14.0s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=500; total time=  35.3s
# [CV] END max_depth=None, max_features=log2, n_estimators=800; total time=  36.0s
# [CV] END max_depth=None, max_features=log2, n_estimators=200; total time=  11.8s
# [CV] END max_depth=None, max_features=log2, n_estimators=500; total time=  28.9s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=200; total time=   6.2s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=   7.4s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=500; total time=  18.3s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=200; total time=  14.1s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=200; total time=  11.0s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=500; total time=  28.0s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=200; total time=  14.0s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=500; total time=  35.5s
# [CV] END max_depth=None, max_features=log2, n_estimators=800; total time=  35.7s
# [CV] END max_depth=None, max_features=log2, n_estimators=200; total time=  11.9s
# [CV] END max_depth=None, max_features=log2, n_estimators=500; total time=  29.2s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=500; total time=  20.5s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=800; total time=  29.5s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=200; total time=  12.8s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=500; total time=  31.8s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=500; total time=  41.5s
# [CV] END max_depth=None, max_features=log2, n_estimators=800; total time=  35.3s
# ['ALPHA_M']
#  Todas las columnas tienen datos válidos, sin valores 999 o -999.
#  Todas las columnas tienen datos válidos, sin valores 9999 o -9999.
# Las siguientes columnas tienen valores nan o -nan:
# ALPHA_M    36
# dtype: int64
# Fitting 10 folds for each of 18 candidates, totalling 180 fits
# [CV] END max_depth=None, max_features=log2, n_estimators=200; total time=  12.5s
# [CV] END max_depth=None, max_features=log2, n_estimators=500; total time=  30.6s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=200; total time=   7.3s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=500; total time=  20.3s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=200; total time=  17.2s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=800; total time= 1.2min
# /home/nicolas/miniconda3/envs/RF/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=   5.4s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=   8.0s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=800; total time=  32.7s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=800; total time= 1.2min
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=   5.4s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=   8.3s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=800; total time=  33.6s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=200; total time=  12.6s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=500; total time=  32.2s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=200; total time=  16.5s
# [CV] END max_depth=None, max_features=log2, n_estimators=200; total time=  12.8s
# [CV] END max_depth=None, max_features=log2, n_estimators=500; total time=  27.1s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=200; total time=   7.5s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=500; total time=  21.1s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=200; total time=  17.9s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=800; total time= 1.2min
# [CV] END max_depth=None, max_features=log2, n_estimators=200; total time=  13.9s
# [CV] END max_depth=None, max_features=log2, n_estimators=800; total time=  45.0s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=800; total time=  39.8s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=500; total time=  43.6s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=200; total time=  17.6s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=500; total time=  43.9s
# [CV] END max_depth=None, max_features=log2, n_estimators=800; total time=  35.4s
# [CV] END max_depth=None, max_features=log2, n_estimators=200; total time=  11.2s
# [CV] END max_depth=None, max_features=log2, n_estimators=500; total time=  27.0s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=200; total time=   6.2s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=500; total time=  18.5s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=200; total time=  15.6s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=800; total time= 1.0min
# [CV] END max_depth=None, max_features=sqrt, n_estimators=500; total time=  38.9s
# [CV] END max_depth=None, max_features=log2, n_estimators=800; total time=  39.9s
# ['C_FE']
#  Todas las columnas tienen datos válidos, sin valores 999 o -999.
#  Todas las columnas tienen datos válidos, sin valores 9999 o -9999.
# Las siguientes columnas tienen valores nan o -nan:
# C_FE    60
# dtype: int64
# Fitting 10 folds for each of 18 candidates, totalling 180 fits
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=800; total time=  39.3s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=800; total time= 1.4min
# /home/nicolas/miniconda3/envs/RF/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=   5.4s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=   5.8s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=800; total time=  32.8s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=800; total time= 1.4min
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=800; total time=  39.7s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=500; total time=  43.7s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=200; total time=  17.7s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=500; total time=  44.4s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=200; total time=   7.1s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=500; total time=  18.7s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=200; total time=  21.2s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=800; total time= 1.4min
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=   5.3s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=   8.0s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=800; total time=  32.6s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=800; total time= 1.2min
# [CV] END max_depth=None, max_features=log2, n_estimators=200; total time=  11.9s
# [CV] END max_depth=None, max_features=log2, n_estimators=500; total time=  29.2s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=200; total time=   6.3s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=   4.9s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=500; total time=  18.8s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=500; total time=  46.7s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=800; total time=  56.6s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=800; total time=  40.3s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=800; total time= 1.2min
# [CV] END max_depth=None, max_features=sqrt, n_estimators=800; total time= 1.0min
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=500; total time=  21.4s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=800; total time=  32.8s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=200; total time=  15.9s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=800; total time= 1.1min
# [CV] END max_depth=None, max_features=log2, n_estimators=200; total time=  10.9s
# [CV] END max_depth=None, max_features=log2, n_estimators=500; total time=  26.5s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=200; total time=   6.2s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=   7.4s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=500; total time=  18.6s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=500; total time=  39.0s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=800; total time=  47.7s
# [CV] END max_depth=None, max_features=log2, n_estimators=200; total time=  11.9s
# [CV] END max_depth=None, max_features=log2, n_estimators=500; total time=  29.6s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=200; total time=   6.3s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=   5.0s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=800; total time=  30.1s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=800; total time= 1.3min
# [CV] END max_depth=None, max_features=sqrt, n_estimators=800; total time= 1.3min
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=   4.8s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=   4.8s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=500; total time=  18.3s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=200; total time=  18.7s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=200; total time=  14.3s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=500; total time=  35.4s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=200; total time=  19.2s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=500; total time=  47.6s
# [CV] END max_depth=None, max_features=log2, n_estimators=800; total time=  47.0s
# ['CA_FE']
#  Todas las columnas tienen datos válidos, sin valores 999 o -999.
#  Todas las columnas tienen datos válidos, sin valores 9999 o -9999.
# Las siguientes columnas tienen valores nan o -nan:
# CA_FE    117
# dtype: int64
# Fitting 10 folds for each of 18 candidates, totalling 180 fits
# [CV] END max_depth=None, max_features=log2, n_estimators=200; total time=  13.6s
# [CV] END max_depth=None, max_features=log2, n_estimators=500; total time=  32.7s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=500; total time=  21.4s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=800; total time=  32.9s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=500; total time=  39.8s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=200; total time=  21.6s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=500; total time=  54.0s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=200; total time=   7.9s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=500; total time=  20.3s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=200; total time=  18.4s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=800; total time= 1.2min
# /home/nicolas/miniconda3/envs/RF/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=   5.9s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=   8.1s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=800; total time=  32.6s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=800; total time= 1.2min
# [CV] END max_depth=None, max_features=log2, n_estimators=200; total time=  16.5s
# [CV] END max_depth=None, max_features=log2, n_estimators=500; total time=  38.4s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=500; total time=  24.1s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=800; total time=  32.6s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=200; total time=  13.9s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=800; total time=  56.6s
# [CV] END max_depth=None, max_features=log2, n_estimators=200; total time=  14.4s
# [CV] END max_depth=None, max_features=log2, n_estimators=500; total time=  35.7s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=200; total time=   6.9s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=   7.4s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=500; total time=  18.3s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=200; total time=  16.3s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=200; total time=  12.2s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=500; total time=  30.6s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=200; total time=  16.3s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=500; total time=  40.5s
# [CV] END max_depth=None, max_features=log2, n_estimators=800; total time=  40.0s
# [CV] END max_depth=None, max_features=log2, n_estimators=200; total time=  14.7s
# [CV] END max_depth=None, max_features=log2, n_estimators=500; total time=  35.7s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=200; total time=   6.9s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=   7.4s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=500; total time=  18.3s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=200; total time=  16.1s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=200; total time=  12.3s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=500; total time=  30.8s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=200; total time=  16.4s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=500; total time=  40.2s
# [CV] END max_depth=None, max_features=log2, n_estimators=800; total time=  40.2s
# ['N_FE']
#  Todas las columnas tienen datos válidos, sin valores 999 o -999.
#  Todas las columnas tienen datos válidos, sin valores 9999 o -9999.
# Las siguientes columnas tienen valores nan o -nan:
# N_FE    46
# dtype: int64
# Fitting 10 folds for each of 18 candidates, totalling 180 fits
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=   6.0s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=   8.4s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=800; total time=  33.5s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=800; total time= 1.3min
# [CV] END max_depth=None, max_features=log2, n_estimators=200; total time=  14.2s
# [CV] END max_depth=None, max_features=log2, n_estimators=500; total time=  30.4s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=500; total time=  23.7s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=200; total time=  20.3s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=800; total time= 1.3min
# /home/nicolas/miniconda3/envs/RF/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=   5.4s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=   7.4s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=800; total time=  33.2s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=800; total time= 1.3min
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=   5.4s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=   7.3s
# ...
# [CV] END max_depth=None, max_features=sqrt, n_estimators=800; total time= 8.8min
# [CV] END max_depth=None, max_features=sqrt, n_estimators=800; total time= 9.6min
# [CV] END max_depth=None, max_features=sqrt, n_estimators=800; total time= 9.1min
# [CV] END max_depth=None, max_features=sqrt, n_estimators=800; total time= 8.6min
# [CV] END max_depth=None, max_features=sqrt, n_estimators=800; total time= 9.0min
# [CV] END max_depth=None, max_features=log2, n_estimators=800; total time= 5.7min
# [CV] END max_depth=None, max_features=log2, n_estimators=800; total time= 5.1min
# [CV] END max_depth=None, max_features=log2, n_estimators=800; total time= 5.7min
# [CV] END max_depth=None, max_features=log2, n_estimators=800; total time= 5.3min
# [CV] END max_depth=None, max_features=log2, n_estimators=800; total time= 5.3min
# ['alpha_m']
#  Todas las columnas tienen datos válidos, sin valores 999 o -999.
# Las siguientes columnas tienen valores 9999 o -9999:
# alpha_m    30823
# dtype: int64
#  Todas las columnas tienen datos válidos, sin valores nan o -nan.
# Fitting 10 folds for each of 18 candidates, totalling 180 fits
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=500; total time= 1.5min
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=200; total time= 1.2min
# /home/nicolas/miniconda3/envs/RF/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=200; total time=  30.7s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=  27.0s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=500; total time= 1.1min
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=200; total time= 1.0min
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=200; total time=  31.0s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=  27.5s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=500; total time= 1.1min
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=200; total time= 1.1min
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=200; total time=  30.8s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=  27.1s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=500; total time= 1.1min
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=200; total time= 1.1min
# [CV] END ..max_depth=30, max_features=log2, n_estimators=200; total time=  48.7s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=800; total time= 2.3min
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=500; total time= 2.6min
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=800; total time= 2.3min
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=500; total time= 2.6min
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=800; total time= 2.3min
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=500; total time= 2.6min
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=800; total time= 2.3min
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=500; total time= 2.7min
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=  25.3s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=  29.7s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=500; total time= 1.2min
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=500; total time= 2.9min
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=  25.4s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=  30.3s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=500; total time= 1.3min
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=500; total time= 3.0min
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=500; total time= 1.4min
# [CV] END ..max_depth=10, max_features=log2, n_estimators=800; total time= 1.8min
# [CV] END ..max_depth=30, max_features=log2, n_estimators=500; total time= 2.0min
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=800; total time= 2.5min
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=500; total time= 2.9min
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=800; total time= 2.5min
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=500; total time= 2.9min
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=800; total time= 2.5min
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=500; total time= 2.9min
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=800; total time= 2.5min
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=500; total time= 3.0min
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=200; total time=  28.5s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=  29.8s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=500; total time= 1.2min
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=200; total time= 1.2min
# [CV] END ..max_depth=30, max_features=log2, n_estimators=500; total time= 2.3min
# [CV] END ..max_depth=30, max_features=log2, n_estimators=200; total time=  48.6s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=500; total time= 2.0min
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=500; total time= 1.4min
# [CV] END ..max_depth=10, max_features=log2, n_estimators=800; total time= 1.8min
# [CV] END ..max_depth=30, max_features=log2, n_estimators=200; total time=  48.3s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=500; total time= 2.0min
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=500; total time= 1.4min
# [CV] END ..max_depth=10, max_features=log2, n_estimators=800; total time= 1.8min
# [CV] END ..max_depth=30, max_features=log2, n_estimators=200; total time=  48.4s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=500; total time= 2.0min
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=500; total time= 1.4min
# [CV] END ..max_depth=10, max_features=log2, n_estimators=800; total time= 1.8min
# [CV] END ..max_depth=30, max_features=log2, n_estimators=200; total time=  48.2s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=500; total time= 2.0min
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=500; total time= 1.4min
# [CV] END ..max_depth=10, max_features=log2, n_estimators=800; total time= 1.8min
# [CV] END ..max_depth=30, max_features=log2, n_estimators=200; total time=  48.4s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=500; total time= 2.0min
# [CV] END ..max_depth=30, max_features=log2, n_estimators=200; total time=  48.9s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=500; total time= 2.1min
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=500; total time= 1.4min
# [CV] END ..max_depth=10, max_features=log2, n_estimators=800; total time= 1.8min
# [CV] END ..max_depth=30, max_features=log2, n_estimators=200; total time=  48.4s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=500; total time= 2.1min
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=200; total time=  31.1s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=  27.5s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=800; total time= 1.8min
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=800; total time= 4.2min
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=800; total time= 2.5min
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=800; total time= 4.7min
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=500; total time= 1.4min
# [CV] END ..max_depth=10, max_features=log2, n_estimators=800; total time= 1.8min
# [CV] END ..max_depth=30, max_features=log2, n_estimators=200; total time=  48.5s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=800; total time= 3.2min
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=500; total time= 1.4min
# [CV] END ..max_depth=10, max_features=log2, n_estimators=800; total time= 1.8min
# [CV] END ..max_depth=30, max_features=log2, n_estimators=200; total time=  48.4s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=800; total time= 3.2min
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=800; total time= 2.6min
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=800; total time= 4.7min
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=500; total time= 1.6min
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=200; total time= 1.2min
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=800; total time= 4.7min
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=200; total time=  34.2s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=  29.4s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=800; total time= 2.0min
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=800; total time= 4.4min
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=200; total time=  34.8s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=500; total time= 1.2min
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=200; total time= 1.2min
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=800; total time= 4.5min
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=200; total time=  34.6s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=500; total time= 1.2min
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=200; total time= 1.2min
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=800; total time= 4.6min
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=200; total time=  34.7s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=500; total time= 1.2min
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=200; total time= 1.2min
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=800; total time= 4.6min
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=200; total time=  35.3s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=500; total time= 1.3min
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=200; total time= 1.2min
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=800; total time= 4.9min
# [CV] END max_depth=None, max_features=sqrt, n_estimators=200; total time= 1.2min
# [CV] END max_depth=None, max_features=sqrt, n_estimators=500; total time= 2.9min
# [CV] END max_depth=None, max_features=sqrt, n_estimators=200; total time= 1.2min
# [CV] END max_depth=None, max_features=sqrt, n_estimators=500; total time= 3.0min
# [CV] END max_depth=None, max_features=sqrt, n_estimators=200; total time= 1.2min
# [CV] END max_depth=None, max_features=sqrt, n_estimators=500; total time= 2.9min
# [CV] END ..max_depth=30, max_features=log2, n_estimators=800; total time= 3.6min
# [CV] END max_depth=None, max_features=log2, n_estimators=500; total time= 1.9min
# [CV] END max_depth=None, max_features=log2, n_estimators=200; total time=  54.9s
# [CV] END max_depth=None, max_features=log2, n_estimators=500; total time= 2.2min
# [CV] END ..max_depth=30, max_features=log2, n_estimators=800; total time= 3.6min
# [CV] END max_depth=None, max_features=log2, n_estimators=500; total time= 2.0min
# [CV] END max_depth=None, max_features=sqrt, n_estimators=200; total time= 1.1min
# [CV] END max_depth=None, max_features=sqrt, n_estimators=800; total time= 4.1min
# [CV] END max_depth=None, max_features=sqrt, n_estimators=200; total time= 1.2min
# [CV] END max_depth=None, max_features=sqrt, n_estimators=800; total time= 4.0min
# [CV] END max_depth=None, max_features=sqrt, n_estimators=200; total time= 1.1min
# [CV] END max_depth=None, max_features=sqrt, n_estimators=800; total time= 4.2min
# [CV] END max_depth=None, max_features=log2, n_estimators=200; total time=  48.5s
# [CV] END max_depth=None, max_features=log2, n_estimators=200; total time=  48.8s
# [CV] END max_depth=None, max_features=log2, n_estimators=800; total time= 2.8min
# [CV] END ..max_depth=30, max_features=log2, n_estimators=500; total time= 2.0min
# [CV] END max_depth=None, max_features=sqrt, n_estimators=200; total time= 1.1min
# [CV] END max_depth=None, max_features=sqrt, n_estimators=500; total time= 2.6min
# [CV] END max_depth=None, max_features=log2, n_estimators=800; total time= 2.6min
# [CV] END max_depth=None, max_features=sqrt, n_estimators=200; total time= 1.2min
# [CV] END max_depth=None, max_features=sqrt, n_estimators=500; total time= 2.9min
# [CV] END max_depth=None, max_features=log2, n_estimators=800; total time= 2.7min
# [CV] END max_depth=None, max_features=sqrt, n_estimators=500; total time= 2.6min
# [CV] END max_depth=None, max_features=log2, n_estimators=800; total time= 2.7min
# [CV] END max_depth=None, max_features=sqrt, n_estimators=200; total time= 1.0min
# [CV] END max_depth=None, max_features=sqrt, n_estimators=500; total time= 2.6min
# [CV] END max_depth=None, max_features=sqrt, n_estimators=500; total time= 2.6min
# [CV] END max_depth=None, max_features=log2, n_estimators=500; total time= 2.0min
# [CV] END max_depth=None, max_features=log2, n_estimators=200; total time=  54.4s
# [CV] END max_depth=None, max_features=log2, n_estimators=500; total time= 2.3min
# [CV] END ..max_depth=30, max_features=log2, n_estimators=800; total time= 3.2min
# [CV] END max_depth=None, max_features=log2, n_estimators=200; total time=  48.3s
# [CV] END max_depth=None, max_features=log2, n_estimators=500; total time= 2.0min
# [CV] END ..max_depth=30, max_features=log2, n_estimators=800; total time= 3.2min
# [CV] END max_depth=None, max_features=log2, n_estimators=200; total time=  48.3s
# [CV] END max_depth=None, max_features=log2, n_estimators=500; total time= 2.0min
# [CV] END ..max_depth=30, max_features=log2, n_estimators=800; total time= 3.2min
# [CV] END max_depth=None, max_features=log2, n_estimators=200; total time=  48.6s
# [CV] END max_depth=None, max_features=log2, n_estimators=500; total time= 2.0min
# [CV] END ..max_depth=30, max_features=log2, n_estimators=800; total time= 3.7min
# [CV] END max_depth=None, max_features=log2, n_estimators=500; total time= 2.2min
# [CV] END max_depth=None, max_features=log2, n_estimators=200; total time=  55.8s
# [CV] END max_depth=None, max_features=log2, n_estimators=500; total time= 2.1min
# [CV] END max_depth=None, max_features=sqrt, n_estimators=800; total time= 4.0min
# [CV] END max_depth=None, max_features=sqrt, n_estimators=800; total time= 4.1min
# [CV] END max_depth=None, max_features=sqrt, n_estimators=800; total time= 4.1min
# [CV] END max_depth=None, max_features=sqrt, n_estimators=800; total time= 4.3min
# [CV] END max_depth=None, max_features=sqrt, n_estimators=800; total time= 4.0min
# [CV] END max_depth=None, max_features=sqrt, n_estimators=800; total time= 4.2min
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=800; total time= 4.7min
# [CV] END max_depth=None, max_features=sqrt, n_estimators=800; total time= 4.3min
# [CV] END ..max_depth=30, max_features=log2, n_estimators=800; total time= 3.2min
# [CV] END max_depth=None, max_features=log2, n_estimators=200; total time=  48.5s
# [CV] END max_depth=None, max_features=log2, n_estimators=800; total time= 2.7min
# [CV] END ..max_depth=30, max_features=log2, n_estimators=800; total time= 3.3min
# [CV] END max_depth=None, max_features=log2, n_estimators=200; total time=  53.9s
# [CV] END max_depth=None, max_features=log2, n_estimators=800; total time= 2.9min
# [CV] END max_depth=None, max_features=sqrt, n_estimators=500; total time= 3.0min
# [CV] END max_depth=None, max_features=log2, n_estimators=800; total time= 2.9min
# [CV] END max_depth=None, max_features=sqrt, n_estimators=200; total time= 1.0min
# [CV] END max_depth=None, max_features=sqrt, n_estimators=500; total time= 2.7min
# [CV] END max_depth=None, max_features=log2, n_estimators=800; total time= 2.4min
# [CV] END max_depth=None, max_features=log2, n_estimators=800; total time= 2.5min
# [CV] END max_depth=None, max_features=log2, n_estimators=800; total time= 2.5min

# %%
directory_path = f'/home/nicolas/nico/Data/Data_Splus/regresion/data/{giagiants}/{survey}/{column}'

# %%
def predict_column(directory_path, survey, column):
    # Cargar el modelo Random Forest
    column_save = column.replace("[","").replace("]","").replace("/","")

    RF = joblib.load(f"{directory_path}/{survey}_{column_save}.sav")

    # Cargar los datos
    df = pd.read_csv(f"{directory_path}/df_{survey}_{column_save}.csv")

    # Filtrar los datos de prueba
    test = df.loc[df["split"] == "test"]

    # Realizar predicciones
    predict_column_name = f"predict_{column}"
    test[predict_column_name] = RF.predict(test[RF.feature_names_in_])

    # Calcular la diferencia entre los valores reales y predichos (y)
    y = test[column] - test[predict_column_name]

    # Extraer los valores reales (x)
    x = test[column]

    # Retorna los valores reales (x) y la diferencia (y)
    return x, y

# %%
column_survey = columns_name[0]
giagiants = "giagiants"
survey = file_names[0]

# %%
# Crear subplots
fig, axes = plt.subplots(nrows=len(column_survey), ncols=1, figsize=(10, len(column_survey) * 5))
axes = axes.flatten()  # Aplanar el array de ejes si es necesario

# Bucle para cada columna y creación de gráficos
for idx, column in enumerate(column_survey):
    directory_path = f'/home/nicolas/nico/Data/Data_Splus/regresion/data/{giagiants}/{survey}/{column}'   
    x, y = predict_column(directory_path, survey, column)
    scatter = axes[idx].scatter(x, y,c="black",s=1,label=f'{column}')
    axes[idx].set_ylabel(f'${{\\Delta {column.replace("_","/")}}}$')
    axes[idx].set_xlabel(f'${{{column.replace("_","/")}}}$')
#axes[idx].set_xlabel(column)
# Adjust the layout and display the plot
plt.tight_layout(rect=[0, 0.03, 1, 0.95])

# Ajustar el layout y mostrar el gráfico
plt.tight_layout()
plt.savefig(f"Regresion_{survey}.pdf")
plt.show()
# Out:
# /tmp/ipykernel_4008/3271167894.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[predict_column_name] = RF.predict(test[RF.feature_names_in_])
# /tmp/ipykernel_4008/3271167894.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[predict_column_name] = RF.predict(test[RF.feature_names_in_])
# /tmp/ipykernel_4008/3271167894.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[predict_column_name] = RF.predict(test[RF.feature_names_in_])
# /tmp/ipykernel_4008/3271167894.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[predict_column_name] = RF.predict(test[RF.feature_names_in_])
# /tmp/ipykernel_4008/3271167894.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[predict_column_name] = RF.predict(test[RF.feature_names_in_])
# /tmp/ipykernel_4008/3271167894.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[predict_column_name] = RF.predict(test[RF.feature_names_in_])
# /tmp/ipykernel_4008/3271167894.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[predict_column_name] = RF.predict(test[RF.feature_names_in_])
# /tmp/ipykernel_4008/3271167894.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[predict_column_name] = RF.predict(test[RF.feature_names_in_])
# /tmp/ipykernel_4008/3271167894.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[predict_column_name] = RF.predict(test[RF.feature_names_in_])
# /tmp/ipykernel_4008/3271167894.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[predict_column_name] = RF.predict(test[RF.feature_names_in_])
